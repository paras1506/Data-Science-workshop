# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10,0.25)

# %%
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %%
y = x * 23.06 + 45.27   # linear function

# %%
y
# Out:
# array([ 45.27 ,  51.035,  56.8  ,  62.565,  68.33 ,  74.095,  79.86 ,
#         85.625,  91.39 ,  97.155, 102.92 , 108.685, 114.45 , 120.215,
#        125.98 , 131.745, 137.51 , 143.275, 149.04 , 154.805, 160.57 ,
#        166.335, 172.1  , 177.865, 183.63 , 189.395, 195.16 , 200.925,
#        206.69 , 212.455, 218.22 , 223.985, 229.75 , 235.515, 241.28 ,
#        247.045, 252.81 , 258.575, 264.34 , 270.105])

# %%
plt.plot(x,y)

# %% [markdown]
# ### Polynomial / quadratic function

# %%
 y = x ** 3 + 56.89

# %%
y
# Out:
# array([ 56.89    ,  56.905625,  57.015   ,  57.311875,  57.89    ,
#         58.843125,  60.265   ,  62.249375,  64.89    ,  68.280625,
#         72.515   ,  77.686875,  83.89    ,  91.218125,  99.765   ,
#        109.624375, 120.89    , 133.655625, 148.015   , 164.061875,
#        181.89    , 201.593125, 223.265   , 246.999375, 272.89    ,
#        301.030625, 331.515   , 364.436875, 399.89    , 437.968125,
#        478.765   , 522.374375, 568.89    , 618.405625, 671.015   ,
#        726.811875, 785.89    , 848.343125, 914.265   , 983.749375])

# %%
plt.plot(x,y);

# %%
plt.plot(x, np.log(x));      # logarithmic growth
# Out:
# C:\Users\Acer\AppData\Local\Temp/ipykernel_19376/2159711818.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x));

# %%
plt.plot(x,np.cos(x))
